# %% [markdown]
# ## 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# 'hello'
#
# -87.8
#
# -
#
# /
#
# +
#
# 6

# %% [markdown]
# values = 'hello', -87.8, 6
#
# expressions = * , - , / , +

# %% [markdown]
# ## 2. What is the difference between string and variable?

# %% [markdown]
# Variable is something that store information of any data type.
#
# String is a data type or text data

# %% [markdown]
# ## 3. Describe three different data types.

# %% [markdown]
# Data types are the classification of data items.
#
# string :  text data
#
# integer : numerical value (1,2,3)
#
# float : decimal value (1.1,2.1,3.3)

# %% [markdown]
# ## 4. What is an expression made up of? What do all expressions do?

# %% [markdown]
# Expression is a combination of variables and operators.
#
# It give us desired output for the input variables.
#
# ex: y = a + b

# %% [markdown]
# ## 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# In assignment statement we assign some value to a variable while in expression we try to compute the output by providing input variables.

# %% [markdown]
# ## 6. After running the following code, what does the variable bacon contain?
# bacon = 22
#
# bacon + 1

# %%
bacon = 22

# %%
bacon + 1
# Out:
# 23

# %%
bacon
# Out:
# 22

# %% [markdown]
# value of bacon variable remain same

# %% [markdown]
# ## 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
#
# 'spam' * 3

# %%
'spam' + 'spamspam'
# Out:
# 'spamspamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# ## 8. Why is eggs a valid variable name while 100 is invalid?

# %%
eggs = 25

# %%
100 = 'eggs'
# Out:
#   File "<ipython-input-7-9dde09b3eb2d>", line 1
#     100 = 'eggs'
#     ^
# SyntaxError: cannot assign to literal

# %% [markdown]
# A variable name cannot start with a number.

# %% [markdown]
# ## 9. What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [markdown]
# int()
#
# float()
#
# str()

# %% [markdown]
# ## 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d24137131a5c> in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %%
'I have eaten ' + str(99) + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'

# %% [markdown]
# concatenation work between strings
