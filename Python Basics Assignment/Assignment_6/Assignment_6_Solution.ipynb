# %% [markdown]
# ### 1. What are escape characters, and how do you use them?

# %% [markdown]
# "\" is a special character, called as escape character. It is used in representing certain whitespace character: "\t" is a tab, "\n" is a newline, and "\r" is carriage return.
#
# Escape characters represent characters in string values that would otherwise be difficult or impossible to type into code.

# %% [markdown]
# ### 2. What do the escape characters n and t stand for?

# %% [markdown]
# "\t" is a tab
#
# "\n" is a newline

# %% [markdown]
# ### 3. What is the way to include backslash characters in a string?

# %% [markdown]
# Use two backslashes to represent a backslash  "\\"

# %% [markdown]
# ### 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# We can use single quote and double qoute to define string. So single quote is fine untill we are using double quote to define string value.

# %% [markdown]
# ### 5. How do you write a string of newlines if you don't want to use the n character?

# %% [markdown]
# We can use triple quote instead of single quote.
# We can add character to the end which indicates that the line is continued on the next line.

# %% [markdown]
# ### 6. What are the values of the given expressions?

# %%
'Hello, world!'[1]
# Out:
# 'e'

# %%
'Hello, world!'[0:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[:5]
# Out:
# 'Hello'

# %%
'Hello, world!'[3:]
# Out:
# 'lo, world!'

# %% [markdown]
# ### 7. What are the values of the following expressions?

# %%
'Hello'.upper()
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper()
# Out:
# True

# %%
'Hello'.upper().lower()
# Out:
# 'hello'

# %% [markdown]
# ### 8. What are the values of the following expressions?

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# ### 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [markdown]
# rjust(), ljust(), and center()

# %% [markdown]
# ### 10. What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
#  lstrip() and rstrip() methods remove whitespace from the left and right ends of a string
