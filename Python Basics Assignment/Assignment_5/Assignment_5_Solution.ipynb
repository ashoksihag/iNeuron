# %% [markdown]
# ### 1. What does an empty dictionary's code look like?

# %%
dict = {}

# %%
print(type(dict))
# Out:
# <class 'dict'>

# %% [markdown]
# ### 2. What is the value of a dictionary value with the key 'foo' and the value 42?

# %%
dict['foo'] = 42

print(dict)
# Out:
# {'foo': 42}

# %% [markdown]
# ### 3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# List is an ordered sequence of object while dictionary is an unordered set.
#
# Items in list can be accessed by there positions while in dictionay we have keys.

# %% [markdown]
# ### 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?

# %%
spam = {'bar':100}

# %%
#key error
spam['foo']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 spam['foo']
#
# KeyError: 'foo'

# %% [markdown]
# ### 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?

# %%
spam = {'bar':100, 'cat':2}

# %%
"cat" in spam
# Out:
# True

# %%
'cat' in spam.keys()
# Out:
# True

# %% [markdown]
# No difference

# %% [markdown]
# ### 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?

# %% [markdown]
# Cat in spam will check for the "cat" in keys while 'cat' in spam.values() will check for 'cat' in values.

# %%
'cat' in spam.values()
# Out:
# False

# %% [markdown]
# ### 7. What is a shortcut for the following code?
# if 'color' not in spam:
#
#     spam['color'] = 'black'

# %%
spam.setdefault('color', 'black')
print(spam)
# Out:
# {'bar': 100, 'cat': 2, 'color': 'black'}

# %% [markdown]
# ### 8. How do you "pretty print" dictionary values using which module and function?

# %%
import pprint

# %%
pprint.pprint(spam)
# Out:
# {'bar': 100, 'cat': 2, 'color': 'black'}
