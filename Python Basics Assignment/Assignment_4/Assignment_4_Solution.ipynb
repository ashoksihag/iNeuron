# %% [markdown]
# ### 1. What exactly is [ ]?

# %% [markdown]
# It is a empty list

# %% [markdown]
# ### 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2,4,6,8,10]

# %%
spam[2]='hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ### 3. What is the value of spam[int(int('3' * 2) / 11)]?

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 8

# %% [markdown]
# ### 4. What is the value of spam[-1]?

# %%
spam.append(['a', 'b', 'c', 'd'] )

# %%
spam
# Out:
# [2, 4, 'hello', 8, 10, ['a', 'b', 'c', 'd']]

# %%
spam[-1]
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### 5. What is the value of spam[:2]?

# %%
spam[:2]
# Out:
# [2, 4]

# %% [markdown]
# ### Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.
# ### 6. What is the value of bacon.index('cat')?

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %%
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ### 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ### 8. How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ### 9. What are the list concatenation and list replication operators?

# %% [markdown]
# concatenation use plus "+"
#
# replication use astrick " * "

# %% [markdown]
# ### 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# append add element at the end of the list.
#
# insert add element at specified index

# %% [markdown]
# ### 11. What are the two methods for removing items from a list?

# %% [markdown]
# list.pop()
#
# list.remove()

# %% [markdown]
# ### 12. Describe how list values and string values are identical.

# %% [markdown]
# Both are ordered collection of elements. List can have different data types while string can only have string data type.

# %% [markdown]
# ### 13. What's the difference between tuples and lists?

# %% [markdown]
# Both are ordered collection.
#
# List are mutable, tuples are immutable.
#
# Tuples are faster than list.
#
# Tuples consume less memory than list.
#
# List is better for performing operations such as insertion and deletion while tuples for acccessing elements
#
# List have several bulit in methods, tuples dont have many built in methods.

# %% [markdown]
# ### 14. How do you type a tuple value that only contains the integer 42?

# %%
t = (42,)

# %% [markdown]
# ### 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %% [markdown]
# typecasting

# %%
bacon = tuple(bacon)
type(bacon)
# Out:
# tuple

# %%
print(type(t))
t = list(t)
print(type(t))
# Out:
# <class 'tuple'>
# <class 'list'>

# %% [markdown]
# ### 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# Variables will contain references to list values rather than list values themselves

# %% [markdown]
# ### 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# copy() create reference to original object. If you change copied object you change the original object.
#
# deepcopy() creates new object and does real copying of original object to new one.
# Changing new deepcopied object doesn't affect original object.
